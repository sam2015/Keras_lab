# %%
import numpy as np
import matplotlib.pyplot as plt
import os
os.environ['KERAS_BACKEND'] = 'theano'
# %matplotlib inline

# %%
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.utils import np_utils
# Out:
# Using Theano backend.

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
print "Train shape:", X_train.shape
print "Label train shape:", y_train.shape
# Out:
# Train shape: (60000, 28, 28)
# Label train shape: (60000,)

# %%
y_train = np_utils.to_categorical(y_train).astype('float32')
y_test = np_utils.to_categorical(y_test)

# %%
y_train.shape
# Out:
# (60000, 10)

# %%
y_test.shape
# Out:
# (10000, 10)

# %%
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(X_train[i], cmap='gray', interpolation='none')
    plt.title("class {}".format(y_train[i]))

# %%
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

X_train /= 255
X_test /= 255

# %%
print "Training matrix shape", X_train.shape
print "Testing matrix shape", X_test.shape
# Out:
# Training matrix shape (60000, 784)
# Testing matrix shape (10000, 784)

# %%
model = Sequential()
model.add(Dense(512, input_shape=(784,)))
model.add(Activation('relu')) # An "activation" is just a non-linear function applied to the output
                              # of the layer above. Here, with a "rectified linear unit",
                              # we clamp all values below 0 to 0.
                           
model.add(Dropout(0.2))   # Dropout helps protect the model from memorizing or "overfitting" the training data
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Dense(10))
model.add(Activation('softmax')) # This special "softmax" activation among other things,
                                 # ensures the output is a valid probaility distribution, that is

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, batch_size=128, nb_epoch=4, verbose=1,validation_data=(X_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/4
# 60000/60000 [==============================] - 20s - loss: 0.2472 - acc: 0.9258 - val_loss: 0.0988 - val_acc: 0.9695
# Epoch 2/4
# 60000/60000 [==============================] - 21s - loss: 0.1016 - acc: 0.9681 - val_loss: 0.0722 - val_acc: 0.9772
# Epoch 3/4
# 60000/60000 [==============================] - 22s - loss: 0.0696 - acc: 0.9781 - val_loss: 0.0746 - val_acc: 0.9777
# Epoch 4/4
# 60000/60000 [==============================] - 26s - loss: 0.0547 - acc: 0.9830 - val_loss: 0.0707 - val_acc: 0.9789

# %%
score = model.evaluate(X_test, y_test)

print "Test score :", score[0]
print "Test accuracy :", score[1]
# Out:
#  9984/10000 [============================>.] - ETA: 0sTest score : 0.0706671083754
# Test accuracy : 0.9789

# %%
predict_class = model.predict_classes(X_test)
test = np_utils.categorical_probas_to_classes(y_test)
# Out:
#  9984/10000 [============================>.] - ETA: 0s

# %%
(predict_class == test).sum()
# Out:
# 9789

# %%
(predict_class != test).sum()
# Out:
# 211

# %%
# Out:
# 0

# %%
img = (X_test[predict_class != test])[0].reshape(28,28)
plt.imshow(img, cmap='gray')
predict_class[predict_class != test][0]
# Out:
# 4

# %%
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, MaxPooling2D
from keras.utils import np_utils
import keras

# %%
np.random.seed(1337)

# %%
batch_size = 200
nb_classes =10
nb_epoch = 4


img_rows, img_cols = 28, 28
nb_filters = 32
pool_size = (2,2)
kernel_size = (3,3)

# %%
(Xtrain, Ytrain), (xtest, ytest) = mnist.load_data()

# %%
if K.image_dim_ordering() == 'th':
    Xtrain = Xtrain.reshape(Xtrain.shape[0], 1, img_rows, img_cols)
    xtest = xtest.reshape(xtest.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    Xtrain = Xtrain.reshape(Xtrain.shape[0], img_rows, img_cols, 1)
    xtest = xtest.reshape(xtest.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

# %%
Xtrain.shape
# Out:
# (60000, 28, 28, 1)

# %%
xtest.shape
# Out:
# (10000, 28, 28, 1)

# %%
Xtrain = Xtrain.astype('float32')
xtest = xtest.astype('float32')
Xtrain /= 255
xtest /= 255
print('X_train shape:', Xtrain.shape)
print(Xtrain.shape[0], 'train samples')
print(xtest.shape[0], 'test samples')
# Out:
# ('X_train shape:', (60000, 28, 28, 1))
# (60000, 'train samples')
# (10000, 'test samples')

# %%
Ytrain = np_utils.to_categorical(Ytrain)
ytest = np_utils.to_categorical(ytest)

# %%
Ytrain.shape
# Out:
# (60000, 10)

# %%
ytest.shape
# Out:
# (10000, 10)

# %%
model = Sequential()

model.add(Convolution2D(nb_filters, kernel_size[0], kernel_size[1],
                        border_mode='valid',
                        input_shape=input_shape)
model.add(Activation('relu'))
model.add(Convolution2D(nb_filters, kernel_size[0], kernel_size[1]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=pool_size))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(nb_classes))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='adadelta',
              metrics=['accuracy'])

# %%
import h5py
from keras.models import model_from_json

# %%
json_file = open('./Conv_model/mnist_conv.json', "r")
load_model = json_file.read()
json_file.close()
loaded_model = model_from_json(load_model)
loaded_model.load_weights('./Conv_model/mnist.h5')

# %%
loaded_model.compile(loss='categorical_crossentropy',optimizer='adadelta',metrics=['accuracy'])

# %%
score = loaded_model.evaluate(xtest, ytest, verbose=1)
# Out:
# 10000/10000 [==============================] - 13s

# %%
print "%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100)
# Out:
# acc: 85.93%

# %%
predict = loaded_model.predict_classes(xtest)
# Out:
# 10000/10000 [==============================] - 13s

# %%
(Xtra, Ytra), (xt, yt) = mnist.load_data()

# %%
(predict == yt).sum()
# Out:
# 8593

# %%
(predict != yt).sum()
# Out:
# 1407

# %%
1 - (1407.0 / 8593.0)
# Out:
# 0.8362620737809845
