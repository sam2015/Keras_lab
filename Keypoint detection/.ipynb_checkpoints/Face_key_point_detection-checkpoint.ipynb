# %%
import os

import numpy as np
from pandas.io.parsers import read_csv
from sklearn.utils import shuffle
from matplotlib import pyplot

# %matplotlib inline

# %%
FTRAIN = 'training.csv'
FTEST = 'test.csv'

def load(test=False, cols=None):
    """testがTrueの場合はFTESTからデータを読み込み、Falseの場合はFTRAINから読み込みます。
    colsにリストが渡された場合にはそのカラムに関するデータのみ返します。
    """

    fname = FTEST if test else FTRAIN
    df = read_csv(os.path.expanduser(fname)) # pandasのdataframeを使用

    # スペースで句切られているピクセル値をnumpy arrayに変換
    df['Image'] = df['Image'].apply(lambda im: np.fromstring(im, sep=' '))

    if cols:  # カラムに関連するデータのみを抽出
        df = df[list(cols) + ['Image']]

    print(df.count())  # カラム毎に値が存在する行数を出力
    df = df.dropna()  # データが欠けている行は捨てる

    X = np.vstack(df['Image'].values) / 255.  # 0から1の値に変換
    X = X.astype(np.float32)

    if not test:  # ラベルが存在するのはFTRAINのみ
        y = df[df.columns[:-1]].values
        y = (y - 48) / 48  # -1から1の値に変換
        X, y = shuffle(X, y, random_state=42)  # データをシャッフル
        y = y.astype(np.float32)
    else:
        y = None

    return X, y

X, y = load()
print("X.shape == {}; X.min == {:.3f}; X.max == {:.3f}".format(
    X.shape, X.min(), X.max()))
print("y.shape == {}; y.min == {:.3f}; y.max == {:.3f}".format(
    y.shape, y.min(), y.max()))
# Out:
# left_eye_center_x            7039
# left_eye_center_y            7039
# right_eye_center_x           7036
# right_eye_center_y           7036
# left_eye_inner_corner_x      2271
# left_eye_inner_corner_y      2271
# left_eye_outer_corner_x      2267
# left_eye_outer_corner_y      2267
# right_eye_inner_corner_x     2268
# right_eye_inner_corner_y     2268
# right_eye_outer_corner_x     2268
# right_eye_outer_corner_y     2268
# left_eyebrow_inner_end_x     2270
# left_eyebrow_inner_end_y     2270
# left_eyebrow_outer_end_x     2225
# left_eyebrow_outer_end_y     2225
# right_eyebrow_inner_end_x    2270
# right_eyebrow_inner_end_y    2270
# right_eyebrow_outer_end_x    2236
# right_eyebrow_outer_end_y    2236
# nose_tip_x                   7049
# nose_tip_y                   7049
# mouth_left_corner_x          2269
# mouth_left_corner_y          2269
# mouth_right_corner_x         2270
# mouth_right_corner_y         2270
# mouth_center_top_lip_x       2275
# mouth_center_top_lip_y       2275
# mouth_center_bottom_lip_x    7016
# mouth_center_bottom_lip_y    7016
# Image                        7049
# dtype: int64
# X.shape == (2140, 9216); X.min == 0.000; X.max == 1.000
# y.shape == (2140, 30); y.min == -0.920; y.max == 0.996

# %%
os.environ['KERAS_BACKEND'] = 'theano'

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import SGD
# Out:
# Using Theano backend.

# %%
model = Sequential()
model.add(Dense(100, input_dim=9216))
model.add(Activation('relu'))
model.add(Dense(30))

sgd = SGD(lr='0.01', momentum=0.9, nesterov=True)
model.compile(loss='mean_squared_error', optimizer=sgd)
hist = model.fit(X, y, nb_epoch=100, validation_split=0.2, verbose=2)
# Out:
# Train on 1712 samples, validate on 428 samples
# Epoch 1/100
# 0s - loss: 0.0617 - val_loss: 0.0150
# Epoch 2/100
# 0s - loss: 0.0130 - val_loss: 0.0113
# Epoch 3/100
# 0s - loss: 0.0105 - val_loss: 0.0126
# Epoch 4/100
# 0s - loss: 0.0098 - val_loss: 0.0108
# Epoch 5/100
# 0s - loss: 0.0091 - val_loss: 0.0091
# Epoch 6/100
# 0s - loss: 0.0086 - val_loss: 0.0088
# Epoch 7/100
# 0s - loss: 0.0083 - val_loss: 0.0083
# Epoch 8/100
# 0s - loss: 0.0078 - val_loss: 0.0079
# Epoch 9/100
# 0s - loss: 0.0074 - val_loss: 0.0078
# Epoch 10/100
# 0s - loss: 0.0072 - val_loss: 0.0075
# Epoch 11/100
# 0s - loss: 0.0070 - val_loss: 0.0073
# Epoch 12/100
# 0s - loss: 0.0067 - val_loss: 0.0074
# Epoch 13/100
# 0s - loss: 0.0066 - val_loss: 0.0071
# Epoch 14/100
# 2s - loss: 0.0064 - val_loss: 0.0069
# Epoch 15/100
# 8s - loss: 0.0062 - val_loss: 0.0067
# Epoch 16/100
# 8s - loss: 0.0060 - val_loss: 0.0066
# Epoch 17/100
# 8s - loss: 0.0058 - val_loss: 0.0065
# Epoch 18/100
# 9s - loss: 0.0058 - val_loss: 0.0063
# Epoch 19/100
# 9s - loss: 0.0055 - val_loss: 0.0062
# Epoch 20/100
# 9s - loss: 0.0056 - val_loss: 0.0062
# Epoch 21/100
# 9s - loss: 0.0054 - val_loss: 0.0061
# Epoch 22/100
# 9s - loss: 0.0052 - val_loss: 0.0076
# Epoch 23/100
# 9s - loss: 0.0052 - val_loss: 0.0067
# Epoch 24/100
# 9s - loss: 0.0050 - val_loss: 0.0057
# Epoch 25/100
# 9s - loss: 0.0050 - val_loss: 0.0056
# Epoch 26/100
# 9s - loss: 0.0049 - val_loss: 0.0055
# Epoch 27/100
# 9s - loss: 0.0048 - val_loss: 0.0055
# Epoch 28/100
# 9s - loss: 0.0047 - val_loss: 0.0054
# Epoch 29/100
# 9s - loss: 0.0046 - val_loss: 0.0053
# Epoch 30/100
# 10s - loss: 0.0045 - val_loss: 0.0055
# Epoch 31/100
# 9s - loss: 0.0044 - val_loss: 0.0052
# Epoch 32/100
# 9s - loss: 0.0044 - val_loss: 0.0055
# Epoch 33/100
# 9s - loss: 0.0044 - val_loss: 0.0051
# Epoch 34/100
# 11s - loss: 0.0043 - val_loss: 0.0051
# Epoch 35/100
# 9s - loss: 0.0042 - val_loss: 0.0050
# Epoch 36/100
# 9s - loss: 0.0041 - val_loss: 0.0048
# Epoch 37/100
# 9s - loss: 0.0041 - val_loss: 0.0049
# Epoch 38/100
# 12s - loss: 0.0040 - val_loss: 0.0049
# Epoch 39/100
# 9s - loss: 0.0039 - val_loss: 0.0049
# Epoch 40/100
# 9s - loss: 0.0039 - val_loss: 0.0048
# Epoch 41/100
# 10s - loss: 0.0039 - val_loss: 0.0046
# Epoch 42/100
# 11s - loss: 0.0038 - val_loss: 0.0047
# Epoch 43/100
# 11s - loss: 0.0038 - val_loss: 0.0046
# Epoch 44/100
# 12s - loss: 0.0037 - val_loss: 0.0046
# Epoch 45/100
# 11s - loss: 0.0037 - val_loss: 0.0045
# Epoch 46/100
# 9s - loss: 0.0036 - val_loss: 0.0049
# Epoch 47/100
# 11s - loss: 0.0036 - val_loss: 0.0045
# Epoch 48/100
# 10s - loss: 0.0036 - val_loss: 0.0045
# Epoch 49/100
# 11s - loss: 0.0035 - val_loss: 0.0047
# Epoch 50/100
# 15s - loss: 0.0035 - val_loss: 0.0044
# Epoch 51/100
# 11s - loss: 0.0035 - val_loss: 0.0044
# Epoch 52/100
# 9s - loss: 0.0034 - val_loss: 0.0047
# Epoch 53/100
# 9s - loss: 0.0034 - val_loss: 0.0044
# Epoch 54/100
# 12s - loss: 0.0033 - val_loss: 0.0044
# Epoch 55/100
# 13s - loss: 0.0033 - val_loss: 0.0041
# Epoch 56/100
# 11s - loss: 0.0032 - val_loss: 0.0041
# Epoch 57/100
# 11s - loss: 0.0032 - val_loss: 0.0041
# Epoch 58/100
# 11s - loss: 0.0032 - val_loss: 0.0041
# Epoch 59/100
# 10s - loss: 0.0032 - val_loss: 0.0041
# Epoch 60/100
# 10s - loss: 0.0031 - val_loss: 0.0044
# Epoch 61/100
# 11s - loss: 0.0031 - val_loss: 0.0041
# Epoch 62/100
# 9s - loss: 0.0030 - val_loss: 0.0041
# Epoch 63/100
# 10s - loss: 0.0030 - val_loss: 0.0041
# Epoch 64/100
# 11s - loss: 0.0030 - val_loss: 0.0040
# Epoch 65/100
# 9s - loss: 0.0030 - val_loss: 0.0046
# Epoch 66/100
# 11s - loss: 0.0030 - val_loss: 0.0039
# Epoch 67/100
# 10s - loss: 0.0030 - val_loss: 0.0042
# Epoch 68/100
# 12s - loss: 0.0029 - val_loss: 0.0039
# Epoch 69/100
# 9s - loss: 0.0028 - val_loss: 0.0039
# Epoch 70/100
# 11s - loss: 0.0028 - val_loss: 0.0040
# Epoch 71/100
# 9s - loss: 0.0028 - val_loss: 0.0038
# Epoch 72/100
# 9s - loss: 0.0028 - val_loss: 0.0039
# Epoch 73/100
# 9s - loss: 0.0028 - val_loss: 0.0037
# Epoch 74/100
# 11s - loss: 0.0028 - val_loss: 0.0037
# Epoch 75/100
# 10s - loss: 0.0027 - val_loss: 0.0037
# Epoch 76/100
# 11s - loss: 0.0027 - val_loss: 0.0037
# Epoch 77/100
# 10s - loss: 0.0027 - val_loss: 0.0042
# Epoch 78/100
# 9s - loss: 0.0027 - val_loss: 0.0037
# Epoch 79/100
# 11s - loss: 0.0027 - val_loss: 0.0038
# Epoch 80/100
# 10s - loss: 0.0026 - val_loss: 0.0037
# Epoch 81/100
# 12s - loss: 0.0026 - val_loss: 0.0037
# Epoch 82/100
# 10s - loss: 0.0026 - val_loss: 0.0035
# Epoch 83/100
# 9s - loss: 0.0026 - val_loss: 0.0037
# Epoch 84/100
# 11s - loss: 0.0026 - val_loss: 0.0036
# Epoch 85/100
# 10s - loss: 0.0025 - val_loss: 0.0036
# Epoch 86/100
# 9s - loss: 0.0025 - val_loss: 0.0035
# Epoch 87/100
# 11s - loss: 0.0025 - val_loss: 0.0035
# Epoch 88/100
# 10s - loss: 0.0025 - val_loss: 0.0036
# Epoch 89/100
# 12s - loss: 0.0025 - val_loss: 0.0036
# Epoch 90/100
# 15s - loss: 0.0025 - val_loss: 0.0035
# Epoch 91/100
# 10s - loss: 0.0025 - val_loss: 0.0035
# Epoch 92/100
# 9s - loss: 0.0024 - val_loss: 0.0035
# Epoch 93/100
# 11s - loss: 0.0025 - val_loss: 0.0035
# Epoch 94/100
# 9s - loss: 0.0024 - val_loss: 0.0036
# Epoch 95/100
# 11s - loss: 0.0024 - val_loss: 0.0035
# Epoch 96/100
# 10s - loss: 0.0024 - val_loss: 0.0035
# Epoch 97/100
# 11s - loss: 0.0024 - val_loss: 0.0035
# Epoch 98/100
# 11s - loss: 0.0024 - val_loss: 0.0035
# Epoch 99/100
# 13s - loss: 0.0023 - val_loss: 0.0034
# Epoch 100/100
# 19s - loss: 0.0023 - val_loss: 0.0034

# %%
pyplot.plot(hist.history['loss'], linewidth=3, label='train')
pyplot.plot(hist.history['val_loss'], linewidth=3, label='valid')
pyplot.grid()
pyplot.legend()
pyplot.xlabel('epoch')
pyplot.ylabel('loss')
pyplot.ylim(1e-3, 1e-2)
pyplot.yscale('log')
pyplot.show()

# %%
def plot_sample(x, y, axis):
    img = x.reshape(96, 96)
    axis.imshow(img, cmap='gray')
    axis.scatter(y[0::2]*48+48, y[1::2]*48+48, marker='x', s=10)

# %%
X_test, _ = load(test=True)
y_test = model.predict(X_test)
# Out:
# ImageId    1783
# Image      1783
# dtype: int64

# %%
fig = pyplot.figure(figsize=(6, 6))
fig.subplots_adjust(
    left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(16):
    axis = fig.add_subplot(4, 4, i+1, xticks=[], yticks=[])
    plot_sample(X_test[i], y_test[i], axis)

pyplot.show()

# %%
y_test.shape
# Out:
# (1783, 30)

# %%
(y_test[0::2]*48+48).shape
# Out:
# (892, 30)

# %%
(y_test[1::2]*48+48).shape
# Out:
# (891, 30)
